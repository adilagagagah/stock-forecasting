# %%
import sys
import os
import pandas as pd
import numpy as np
from datetime import datetime, timedelta
from pathlib import Path
import warnings
warnings.filterwarnings('ignore')

# Import modul internal proyek Anda
sys.path.append(os.path.abspath(os.path.join('..')))
from src.data_loader import load_stock_data, dataset_splitting
from src.visualizer import plot_interactive_candlestick
from src.features import create_features          # Sesuaikan nama fungsi jika berbeda
from src.label import create_labels                # Sesuaikan nama fungsi jika berbeda
from src.risk_manager import evaluate_trade_risk   # Otak manajemen risiko kuantitatif
from src.backtest import WalkForwardBacktester

print("✓ Seluruh modul berhasil diimpor.")
# Out:
# ✓ Seluruh modul berhasil diimpor.

# %%
# 1. Unduh Data Historis Saham
ticker_target = "BUMI.JK"
IN_SAMPLE_START = "2014-11-01"
IN_SAMPLE_END = '2023-12-31'    # Data latih: 2015 - 2023
OOS_START = '2024-01-01'        # Data uji: 2024 - 2025
OOS_END = '2025-12-31'
TODAY = datetime.now().strftime('%Y-%m-%d')
end_date_today = datetime.now().strftime('%Y-%m-%d')

df_bumi = load_stock_data(ticker=ticker_target, start_date=IN_SAMPLE_START, end_date=TODAY)
# Out:
# Mengunduh data terbaru untuk BUMI.JK dari Yahoo Finance...
# Berhasil memuat 2911 baris data untuk BUMI.JK.
# Info Data Cleaning: Menghapus 123 baris data (NaN atau Volume 0).
# Berhasil memuat 2788 baris data bersih untuk BUMI.JK.

# %%
# 2. Replikasi Rekayasa Fitur (X) & Target Label (y)
df_features = create_features(df_bumi.copy()) # Panggil fungsi dari features.py
df_labels = create_labels(df_bumi.copy())     # Panggil fungsi dari label.py

# Ekstrak daftar kolom fitur (mengabaikan kolom NaN)
feature_cols = [col for col in df_features.columns if col not in ['Open', 'High', 'Low', 'Close', 'Volume']]

# 3. Pisahkan Data ke Fase In-Sample & Out-of-Sample menggunakan dataset_splitting
X_in, y_in_raw, X_oos, y_oos_raw, _, _ = dataset_splitting(df_features, df_labels, IN_SAMPLE_START, IN_SAMPLE_END, OOS_START, "2026-08-31")

# Bungkus dictionary target label untuk memfasilitasi 5 model
y_in_dict = {target: y_in_raw[target] for target in ['trend_slope', 'return', 'risk', 'days_to_max', 'days_to_min']}
y_oos_dict = {target: y_oos_raw[target] for target in ['trend_slope', 'return', 'risk', 'days_to_max', 'days_to_min']}

# 4. Inisialisasi & Jalankan Backtest
backtester = WalkForwardBacktester(
    ticker=ticker_target,
    min_dip_proba=1,
    min_rr_ratio=1.1,
    max_risk_pct=0.06,
    max_alloc_pct=0.5,
    max_holding_days=3,
    fee_buy=0.0015,
    fee_sell=0.0025,
    initial_capital=5_000_000.0,
)

# Jalankan simulasi pada data Out-of-Sample (2024 - 2025)
df_trades_result, df_equity_curve = backtester.run_backtest(
    X_in=X_in,
    y_in_dict=y_in_dict,
    X_oos=X_oos,
    y_oos_dict=y_oos_dict,
    df_raw_prices=df_bumi,
    feature_cols=feature_cols
)
# Out:
# ======================================================================
#  MEMULAI SIMULASI WALK-FORWARD ANALYSIS (BUMI.JK)
#  Modal Awal: Rp5,000,000.00
# ======================================================================
#
# [INIT] Memuat model awal dari folder models/bumi...
# --------------------------------------------------
# PERIODE KELOLAAN: 2024-01 | OOS: 22 Hari Bursa
# --------------------------------------------------
#
# [RETRAIN] Melatih ulang 4 model dengan data Expanding Window (2181 baris)...
# [RETRAIN] Seluruh model berhasil diperbarui.
#
# --------------------------------------------------
# PERIODE KELOLAAN: 2024-02 | OOS: 18 Hari Bursa
# --------------------------------------------------
#
# [RETRAIN] Melatih ulang 4 model dengan data Expanding Window (2199 baris)...
# [RETRAIN] Seluruh model berhasil diperbarui.
#
# --------------------------------------------------
# PERIODE KELOLAAN: 2024-03 | OOS: 18 Hari Bursa
# --------------------------------------------------
#
# [RETRAIN] Melatih ulang 4 model dengan data Expanding Window (2217 baris)...
# [RETRAIN] Seluruh model berhasil diperbarui.
#
# --------------------------------------------------
# PERIODE KELOLAAN: 2024-04 | OOS: 16 Hari Bursa
# --------------------------------------------------
#
# [RETRAIN] Melatih ulang 4 model dengan data Expanding Window (2233 baris)...
# [RETRAIN] Seluruh model berhasil diperbarui.
#
# --------------------------------------------------
# PERIODE KELOLAAN: 2024-05 | OOS: 18 Hari Bursa
# --------------------------------------------------
#   [BUY LOG]  2024-05-03 | Beli [STRONG UPTREND] @ Rp98.00   | Lot: 254  | Modal : Rp2,492,933.80            | Ekuitas: Rp5,000,000.00
#        |->  [REASON] Dip: 14.17% | Slope: 0.0000 | Ret: 14.17% | Risk: -5.72% | RR: 2.13 | Dip: 14.16%
#        |->  [TARGET] TP: 112.00  | SL: 92.00
#   [SELL LOG] 2024-05-15 | Jual (EMA 5/10 Cross  ) @ Rp93.00   | Lot: 254  | Profit: Rp-136,639.30 ( -5.48%) | Ekuitas: Rp4,863,360.70
#
#
# [RETRAIN] Melatih ulang 4 model dengan data Expanding Window (2251 baris)...
# [RETRAIN] Seluruh model berhasil diperbarui.
#
# --------------------------------------------------
# PERIODE KELOLAAN: 2024-06 | OOS: 18 Hari Bursa
# --------------------------------------------------
#
# [RETRAIN] Melatih ulang 4 model dengan data Expanding Window (2269 baris)...
# [RETRAIN] Seluruh model berhasil diperbarui.
#
# --------------------------------------------------
# PERIODE KELOLAAN: 2024-07 | OOS: 23 Hari Bursa
# --------------------------------------------------
#
# [RETRAIN] Melatih ulang 4 model dengan data Expanding Window (2292 baris)...
# [RETRAIN] Seluruh model berhasil diperbarui.
#
# --------------------------------------------------
# PERIODE KELOLAAN: 2024-08 | OOS: 22 Hari Bursa
# --------------------------------------------------
#
# [RETRAIN] Melatih ulang 4 model dengan data Expanding Window (2314 baris)...
# [RETRAIN] Seluruh model berhasil diperbarui.
#
# --------------------------------------------------
# PERIODE KELOLAAN: 2024-09 | OOS: 20 Hari Bursa
# --------------------------------------------------
#   [BUY LOG]  2024-09-02 | Beli [STRONG UPTREND] @ Rp89.00   | Lot: 272  | Modal : Rp2,424,431.20            | Ekuitas: Rp4,863,360.70
#        |->  [REASON] Dip: 8.39% | Slope: 0.0000 | Ret: 8.39% | Risk: -6.18% | RR: 1.24 | Dip: 12.21%
#        |->  [TARGET] TP: 96.00   | SL: 84.00
#
# [RETRAIN] Melatih ulang 4 model dengan data Expanding Window (2334 baris)...
# [RETRAIN] Seluruh model berhasil diperbarui.
#
# --------------------------------------------------
# PERIODE KELOLAAN: 2024-10 | OOS: 23 Hari Bursa
# --------------------------------------------------
#   [SELL LOG] 2024-10-31 | Jual (EMA 5/10 Cross  ) @ Rp139.00  | Lot: 272  | Profit: Rp1,346,916.80 (+55.56%) | Ekuitas: Rp6,210,277.50
#
#
# [RETRAIN] Melatih ulang 4 model dengan data Expanding Window (2357 baris)...
# [RETRAIN] Seluruh model berhasil diperbarui.
#
# --------------------------------------------------
# PERIODE KELOLAAN: 2024-11 | OOS: 20 Hari Bursa
# --------------------------------------------------
#   [BUY LOG]  2024-11-01 | Beli [NORMAL]         @ Rp139.00  | Lot: 223  | Modal : Rp3,104,349.55            | Ekuitas: Rp6,210,277.50
#        |->  [REASON] Dip: 9.13% | Slope: 0.0146 | Ret: 9.13% | Risk: -6.25% | RR: 1.30 | Dip: 7.34%
#        |->  [TARGET] TP: 152.00  | SL: 130.00
#   [SELL LOG] 2024-11-06 | Jual (Time-Stop       ) @ Rp135.00  | Lot: 223  | Profit: Rp-101,375.80 ( -3.27%) | Ekuitas: Rp6,108,901.70
#
#   [BUY LOG]  2024-11-19 | Beli [STRONG UPTREND] @ Rp153.00  | Lot: 199  | Modal : Rp3,049,267.05            | Ekuitas: Rp6,108,901.70
#        |->  [REASON] Dip: 17.12% | Slope: 0.0291 | Ret: 17.12% | Risk: -7.15% | RR: 2.19 | Dip: 12.87%
#        |->  [TARGET] TP: 179.00  | SL: 142.00
#   [SELL LOG] 2024-11-21 | Jual (EMA 5/10 Cross  ) @ Rp143.00  | Lot: 199  | Profit: Rp-210,681.30 ( -6.91%) | Ekuitas: Rp5,898,220.40
#
#
# [RETRAIN] Melatih ulang 4 model dengan data Expanding Window (2377 baris)...
# [RETRAIN] Seluruh model berhasil diperbarui.
#
# --------------------------------------------------
# PERIODE KELOLAAN: 2024-12 | OOS: 19 Hari Bursa
# --------------------------------------------------
#
# [RETRAIN] Melatih ulang 4 model dengan data Expanding Window (2396 baris)...
# [RETRAIN] Seluruh model berhasil diperbarui.
#
# --------------------------------------------------
# PERIODE KELOLAAN: 2025-01 | OOS: 19 Hari Bursa
# --------------------------------------------------
#
# [RETRAIN] Melatih ulang 4 model dengan data Expanding Window (2415 baris)...
# [RETRAIN] Seluruh model berhasil diperbarui.
#
# --------------------------------------------------
# PERIODE KELOLAAN: 2025-02 | OOS: 20 Hari Bursa
# --------------------------------------------------
#
# [RETRAIN] Melatih ulang 4 model dengan data Expanding Window (2435 baris)...
# [RETRAIN] Seluruh model berhasil diperbarui.
#
# --------------------------------------------------
# PERIODE KELOLAAN: 2025-03 | OOS: 19 Hari Bursa
# --------------------------------------------------
#
# [RETRAIN] Melatih ulang 4 model dengan data Expanding Window (2454 baris)...
# [RETRAIN] Seluruh model berhasil diperbarui.
#
# --------------------------------------------------
# PERIODE KELOLAAN: 2025-04 | OOS: 16 Hari Bursa
# --------------------------------------------------
#
# [RETRAIN] Melatih ulang 4 model dengan data Expanding Window (2470 baris)...
# [RETRAIN] Seluruh model berhasil diperbarui.
#
# --------------------------------------------------
# PERIODE KELOLAAN: 2025-05 | OOS: 17 Hari Bursa
# --------------------------------------------------
#   [BUY LOG]  2025-05-15 | Beli [STRONG UPTREND] @ Rp119.00  | Lot: 247  | Modal : Rp2,943,708.95            | Ekuitas: Rp5,898,220.40
#        |->  [REASON] Dip: 8.83% | Slope: 0.0020 | Ret: 8.83% | Risk: -6.32% | RR: 1.24 | Dip: 16.32%
#        |->  [TARGET] TP: 130.00  | SL: 111.00
#
# [RETRAIN] Melatih ulang 4 model dengan data Expanding Window (2487 baris)...
# [RETRAIN] Seluruh model berhasil diperbarui.
#
# --------------------------------------------------
# PERIODE KELOLAAN: 2025-06 | OOS: 18 Hari Bursa
# --------------------------------------------------
#   [SELL LOG] 2025-06-19 | Jual (EMA 5/10 Cross  ) @ Rp121.00  | Lot: 247  | Profit: Rp 37,519.30 ( +1.27%) | Ekuitas: Rp5,935,739.70
#
#
# [RETRAIN] Melatih ulang 4 model dengan data Expanding Window (2505 baris)...
# [RETRAIN] Seluruh model berhasil diperbarui.
#
# --------------------------------------------------
# PERIODE KELOLAAN: 2025-07 | OOS: 23 Hari Bursa
# --------------------------------------------------
#
# [RETRAIN] Melatih ulang 4 model dengan data Expanding Window (2528 baris)...
# [RETRAIN] Seluruh model berhasil diperbarui.
#
# --------------------------------------------------
# PERIODE KELOLAAN: 2025-08 | OOS: 20 Hari Bursa
# --------------------------------------------------
#
# [RETRAIN] Melatih ulang 4 model dengan data Expanding Window (2548 baris)...
# [RETRAIN] Seluruh model berhasil diperbarui.
#
# --------------------------------------------------
# PERIODE KELOLAAN: 2025-09 | OOS: 21 Hari Bursa
# --------------------------------------------------
#
# [RETRAIN] Melatih ulang 4 model dengan data Expanding Window (2569 baris)...
# [RETRAIN] Seluruh model berhasil diperbarui.
#
# --------------------------------------------------
# PERIODE KELOLAAN: 2025-10 | OOS: 23 Hari Bursa
# --------------------------------------------------
#   [BUY LOG]  2025-10-02 | Beli [STRONG UPTREND] @ Rp163.00  | Lot: 181  | Modal : Rp2,954,725.45            | Ekuitas: Rp5,935,739.70
#        |->  [REASON] Dip: 13.35% | Slope: 0.0063 | Ret: 13.35% | Risk: -7.92% | RR: 1.56 | Dip: 19.68%
#        |->  [TARGET] TP: 185.00  | SL: 150.00
#   [SELL LOG] 2025-10-10 | Jual (EMA 5/10 Cross  ) @ Rp138.00  | Lot: 181  | Profit: Rp-463,169.95 (-15.68%) | Ekuitas: Rp5,472,569.75
#
#
# [RETRAIN] Melatih ulang 4 model dengan data Expanding Window (2592 baris)...
# [RETRAIN] Seluruh model berhasil diperbarui.
#
# --------------------------------------------------
# PERIODE KELOLAAN: 2025-11 | OOS: 20 Hari Bursa
# --------------------------------------------------
#   [BUY LOG]  2025-11-06 | Beli [STRONG UPTREND] @ Rp142.00  | Lot: 192  | Modal : Rp2,730,489.60            | Ekuitas: Rp5,472,569.75
#        |->  [REASON] Dip: 8.04% | Slope: 0.0011 | Ret: 8.04% | Risk: -5.54% | RR: 1.22 | Dip: 13.83%
#        |->  [TARGET] TP: 153.00  | SL: 134.00
#
# [RETRAIN] Melatih ulang 4 model dengan data Expanding Window (2612 baris)...
# [RETRAIN] Seluruh model berhasil diperbarui.
#
# --------------------------------------------------
# PERIODE KELOLAAN: 2025-12 | OOS: 20 Hari Bursa
# --------------------------------------------------
#
# [RETRAIN] Melatih ulang 4 model dengan data Expanding Window (2632 baris)...
# [RETRAIN] Seluruh model berhasil diperbarui.
#
# --------------------------------------------------
# PERIODE KELOLAAN: 2026-01 | OOS: 20 Hari Bursa
# --------------------------------------------------
#   [SELL LOG] 2026-01-19 | Jual (EMA 5/10 Cross  ) @ Rp412.00  | Lot: 192  | Profit: Rp5,160,134.40 (+188.98%) | Ekuitas: Rp10,632,704.15
#
#
# [RETRAIN] Melatih ulang 4 model dengan data Expanding Window (2652 baris)...
# [RETRAIN] Seluruh model berhasil diperbarui.
#
# --------------------------------------------------
# PERIODE KELOLAAN: 2026-02 | OOS: 18 Hari Bursa
# --------------------------------------------------
#
# [RETRAIN] Melatih ulang 4 model dengan data Expanding Window (2670 baris)...
# [RETRAIN] Seluruh model berhasil diperbarui.
#
# --------------------------------------------------
# PERIODE KELOLAAN: 2026-03 | OOS: 17 Hari Bursa
# --------------------------------------------------
#
# [RETRAIN] Melatih ulang 4 model dengan data Expanding Window (2687 baris)...
# [RETRAIN] Seluruh model berhasil diperbarui.
#
# --------------------------------------------------
# PERIODE KELOLAAN: 2026-04 | OOS: 21 Hari Bursa
# --------------------------------------------------
#
# [RETRAIN] Melatih ulang 4 model dengan data Expanding Window (2708 baris)...
# [RETRAIN] Seluruh model berhasil diperbarui.
#
# --------------------------------------------------
# PERIODE KELOLAAN: 2026-05 | OOS: 16 Hari Bursa
# --------------------------------------------------
#
# [RETRAIN] Melatih ulang 4 model dengan data Expanding Window (2724 baris)...
# [RETRAIN] Seluruh model berhasil diperbarui.
#
# --------------------------------------------------
# PERIODE KELOLAAN: 2026-06 | OOS: 20 Hari Bursa
# --------------------------------------------------
#
# [RETRAIN] Melatih ulang 4 model dengan data Expanding Window (2744 baris)...
# [RETRAIN] Seluruh model berhasil diperbarui.
#
# --------------------------------------------------
# PERIODE KELOLAAN: 2026-07 | OOS: 23 Hari Bursa
# --------------------------------------------------
#
# [RETRAIN] Melatih ulang 4 model dengan data Expanding Window (2767 baris)...
# [RETRAIN] Seluruh model berhasil diperbarui.
#
# --------------------------------------------------
# PERIODE KELOLAAN: 2026-08 | OOS: 19 Hari Bursa
# --------------------------------------------------
#   [BUY LOG]  2026-08-20 | Beli [STRONG UPTREND] @ Rp184.00  | Lot: 288  | Modal : Rp5,307,148.80            | Ekuitas: Rp10,632,704.15
#        |->  [REASON] Dip: 18.96% | Slope: 0.0021 | Ret: 18.96% | Risk: -5.42% | RR: 3.10 | Dip: 13.11%
#        |->  [TARGET] TP: 218.00  | SL: 174.00
#
# [RETRAIN] Melatih ulang 4 model dengan data Expanding Window (2786 baris)...
# [RETRAIN] Seluruh model berhasil diperbarui.
#
#
# [INFO] Menutup paksa 1 posisi aktif di akhir backtest (2026-08-31)
#   [SELL LOG] 2026-08-31 | Jual (Akhir Backtest  ) @ Rp192.00  | Lot: 288  | Profit: Rp208,627.20 ( +3.93%) | Ekuitas: Rp10,841,331.35
#
#
# ======================================================================
#                 RINGKASAN PERFORMA BACKTEST (WFA)
# ======================================================================
#  Modal Awal            : Rp5,000,000.00
#  Modal Akhir           : Rp10,841,331.35
#  Total Net Return      : Rp5,841,331.35 (+116.83%)
#  Expected Value (EV)   : Rp730,166.42 / trade
#  Total Transaksi       : 8
#  Win Rate              : 50.00% (4 Menang / 4 Kalah)
# ======================================================================

# %%
# Menampilkan grafik interaktif yang berisi Candlestick, Volume, dan Hasil Prediksi
plot_interactive_candlestick(
    df=df_bumi,               # Dataframe OHLCV saham (sesuaikan nama variabel jika berbeda)
    ticker_name=ticker_target,
    start_date="2024-01-01",  # Opsional: sesuaikan rentang zoom awal jika diperlukan
    end_date="2026-08-31",
    predictions_df=backtester.predictions_df,  # Ambil data dari objek backtester
    df_equity=df_equity_curve,           # Diambil dari output run_backtest()
    df_trades=df_trades_result,                 # Diambil dari output run_backtest()
    show_raw_buy_signals=True
)

# %%
# 1. Melihat Distribusi Alasan Terjual (Exit Reason)
print("=== DISTRIBUSI ALASAN JUAL ===")
display(df_trades_result['exit_reason'].value_counts())
print("\nDalam bentuk persentase:")
display(df_trades_result['exit_reason'].value_counts(normalize=True) * 100)

# 2. Melihat Distribusi Hari untuk status 'Time-Stop'
print("\n=== DISTRIBUSI HARI UNTUK TIME-STOP ===")
time_stop_df = df_trades_result[df_trades_result['exit_reason'] == 'Time-Stop']
display(time_stop_df['days_held'].value_counts().sort_index())

# Opsional: Jika ingin divisualisasikan dalam bentuk grafik (Bar Chart)
import matplotlib.pyplot as plt

fig, axes = plt.subplots(1, 2, figsize=(14, 5))

# Plot Alasan Terjual
df_trades_result['exit_reason'].value_counts().plot(kind='bar', ax=axes[0], color=['green', 'red', 'orange', 'grey'])
axes[0].set_title('Distribusi Alasan Terjual')
axes[0].set_ylabel('Jumlah Transaksi')
axes[0].tick_params(axis='x', rotation=0)

# Plot Hari Time-Stop
if not time_stop_df.empty:
    time_stop_df['days_held'].value_counts().sort_index().plot(kind='bar', ax=axes[1], color='orange')
    axes[1].set_title('Distribusi Time-Stop Berdasarkan Lama Hari (days_held)')
    axes[1].set_xlabel('Hari Ke-')
    axes[1].set_ylabel('Jumlah Transaksi')
    axes[1].tick_params(axis='x', rotation=0)
else:
    axes[1].set_title('Tidak Ada Transaksi Time-Stop')

plt.tight_layout()
plt.show()
# Out:
# === DISTRIBUSI ALASAN JUAL ===
# exit_reason
# EMA 5/10 Cross    6
# Time-Stop         1
# Akhir Backtest    1
# Name: count, dtype: int64
# Dalam bentuk persentase:
# exit_reason
# EMA 5/10 Cross    75.0
# Time-Stop         12.5
# Akhir Backtest    12.5
# Name: proportion, dtype: float64
# === DISTRIBUSI HARI UNTUK TIME-STOP ===
# days_held
# 3    1
# Name: count, dtype: int64

# %%
final_equity = df_equity_curve.iloc[-1]['total_equity']
save_csv_path=f"../data/processed/jurnal_trading_{final_equity:,.2f}_{backtester.max_risk_pct}_{backtester.max_alloc_pct}_{backtester.min_rr_ratio}.csv"
df_journal = backtester.save_trade_history_to_csv(df_bumi, save_csv_path)

# Tampilkan jurnal
display(df_journal.tail(10))
# Out:
# [INFO] Jurnal berhasil disimpan ke: ../data/processed/jurnal_trading_10,855,155.35_0.06_0.5_1.1.csv
#               Open    High     Low   Close         Volume Keputusan  \
# Date
# 2026-08-14  178.00  183.00  174.00  181.00  2,030,936,400         -
# 2026-08-18  183.00  187.00  182.00  184.00  2,230,547,000         -
# 2026-08-19  184.00  185.00  181.00  182.00  1,046,473,100         -
# 2026-08-20  184.00  191.00  183.00  190.00  3,546,576,700       Buy
# 2026-08-21  191.00  202.00  189.00  196.00  6,243,279,400         -
# 2026-08-24  199.00  202.00  193.00  194.00  3,431,299,700         -
# 2026-08-26  194.00  195.00  184.00  184.00  2,738,635,400         -
# 2026-08-27  181.00  194.00  181.00  194.00  2,732,850,200         -
# 2026-08-28  195.00  198.00  189.00  190.00  2,901,144,900         -
# 2026-08-31  190.00  194.00  188.00  192.00  1,586,243,800      Sell
#
#            Harga Eksekusi  Lot Value Transaksi      Invested      Sisa Cash  \
# Date
# 2026-08-14           0.00    0            0.00          0.00  10,632,704.15
# 2026-08-18           0.00    0            0.00          0.00  10,632,704.15
# 2026-08-19           0.00    0            0.00          0.00  10,632,704.15
# 2026-08-20         184.00  288    5,307,148.80  5,472,000.00   5,325,555.35
# 2026-08-21           0.00    0            0.00  5,644,800.00   5,325,555.35
# 2026-08-24           0.00    0            0.00  5,587,200.00   5,325,555.35
# 2026-08-26           0.00    0            0.00  5,299,200.00   5,325,555.35
# 2026-08-27           0.00    0            0.00  5,587,200.00   5,325,555.35
# 2026-08-28           0.00    0            0.00  5,472,000.00   5,325,555.35
# 2026-08-31         192.00  288    5,515,776.00  5,529,600.00   5,325,555.35
#
#              Total Equity
# Date
# 2026-08-14  10,632,704.15
# 2026-08-18  10,632,704.15
# 2026-08-19  10,632,704.15
# 2026-08-20  10,797,555.35
# 2026-08-21  10,970,355.35
# 2026-08-24  10,912,755.35
# 2026-08-26  10,624,755.35
# 2026-08-27  10,912,755.35
# 2026-08-28  10,797,555.35
# 2026-08-31  10,855,155.35
